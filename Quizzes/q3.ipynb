# %% [markdown]
# ### Quiz Notes
#
# **Question 1**
# 0.1 out of 0.1 points
#
# What would be displayed in the console for this code?
#
# ```python
# word = 'Millenium'
# print(len(word))
# ```
# Selected Answer:
# Correct
# 9
#
# Correct Answer:
# Correct
# 9
#
# ---
#
# **Question 2**
# 0.1 out of 0.1 points
#
# What will be displayed in the console for this code?
#
# ```python
# name = input('Please enter your name')
# ```
# Selected Answer:
# Correct
# Please enter your name
#
# Correct Answer:
# Correct
# Please enter your name
#
# ---
#
# **Question 3**
# 0.1 out of 0.1 points
#
# What would be displayed in the console for this code:
#
# ```python
# lottoNumbers = [2, 32, 44, 12, 32, 41]
# lottoNumbers.pop(2)
# print(lottoNumbers)
# ```
# Selected Answer:
# Correct
# [2, 32, 12, 32, 41]
#
# Correct Answer:
# Correct
# [2, 32, 12, 32, 41]
#
# ---
#
# **Question 4**
# 0.1 out of 0.1 points
#
# What would be displayed in the console for this code:
#
# ```python
# studentGrades = {
#           'Mike': 78,
#           'Sully': 94,
#           'Randall': 32,
#           'Celia': 99
# }
#
# studentGrades['Mike'] = 99
#
# print(studentGrades)
# ```
# Selected Answer:
# Correct
# {'Mike': 99, 'Sully': 94, 'Randall': 32, 'Celia': 99}
#
# Correct Answer:
# Correct
# {'Mike': 99, 'Sully': 94, 'Randall': 32, 'Celia': 99}
#
# ---
#
# **Question 5**
# 0.1 out of 0.1 points
#
# Sets are ordered collections of unique types. Elements can be identified by position, but no repeating elements are allowed.
#
# Selected Answer:
# Correct
# False
#
# Correct Answer:
# Correct
# False
#
# ---
#
# **Question 6**
# 0.1 out of 0.1 points
#
# What would be printed in the console for this code?
#
# ```python
# lottoNumbers = [2, 32, 44, 12, 32, 41]
# print(lottoNumbers[0])
# ```
# Selected Answer:
# Correct
# 2
#
# Correct Answer:
# Correct
# 2
#
# ---
#
# **Question 7**
# 0.1 out of 0.1 points
#
# What would be output in the console from this code?
#
# ```python
# print("Hello", end='')
# print(" World!")
# ```
# Selected Answer:
# Correct
# Hello World!
#
# Correct Answer:
# Correct
# Hello World!
#
# ---
#
# **Question 8**
# 0.1 out of 0.1 points
#
# What would be displayed in the console for the following code:
#
# ```python
# name = 'Frankenstein'
# print(name[3])
# ```
# Selected Answer:
# Correct
# n
#
# Correct Answer:
# Correct
# n
#
# ---
#
# **Question 9**
# 0 out of 0.1 points
#
# In this example - "How many would you like?" is best described as:
#
# ```python
# qty = input('How many would you like?')
# ```
# Selected Answer:
# Incorrect
# a variable
#
# Correct Answer:
# Correct
# an argument
#
# ---
#
# **Question 10**
# 0.1 out of 0.1 points
#
# What would be displayed in the console for this code?
#
# ```python
# word1 = 'This'
# word2 = 'is'
# word3 = 'amazing!'
#
# print(word1 + word2 + word3)
# ```
# Selected Answer:
# Correct
# Thisisamazing!
#
# Correct Answer:
# Correct
# Thisisamazing!
