# %% [markdown]
# ### Python Quiz 4
#
# #### Question 1
# 0.1 out of 0.1 points
#
# In Python, …………………. defines a block of statements.
#
# **Selected Answer:**
# Correct
# indentation
#
# **Correct Answer:**
# Correct
# indentation
#
# #### Question 2
# 0.1 out of 0.1 points
#
# When deciding the possible number of outcomes, the number of combinations is 3 raised to the power of the number of conditions. For example, if there are 2 possible outcomes, there are 9 different combinations that could result.
#
# **Selected Answer:**
# Correct
# False
#
# **Correct Answer:**
# Correct
# False
#
# #### Question 3
# 0.1 out of 0.1 points
#
# After running this code, what will be displayed in the console?
#
# ```python
# yrsService = 32
# result = "You cannot retire!" if yrsService < 30 else "Happy retirement!"
# print(result)
# ```
#
# **Selected Answer:**
# Correct
# Happy retirement!
#
# **Correct Answer:**
# Correct
# Happy retirement!
#
# #### Question 4
# 0.1 out of 0.1 points
#
# A ____ expression has one of two values: True or False
#
# **Selected Answer:**
# Correct
# Boolean
#
# **Correct Answer:**
# Correct
# Boolean
#
# #### Question 5
# 0.1 out of 0.1 points
#
# All of these are valid comparison operators EXCEPT for:
#
# **Selected Answer:**
# Correct
# =>
#
# **Correct Answer:**
# Correct
# =>
#
# #### Question 6
# 0.1 out of 0.1 points
#
# When running this code, "I am" is printed in the console
#
# ```python
# name = "I am"
# otherName = name
#
# if otherName is name:
#           print("I am")
# ```
#
# **Selected Answer:**
# Correct
# True
#
# **Correct Answer:**
# Correct
# True
#
# #### Question 7
# 0.1 out of 0.1 points
#
# When running this code, the result will display "There"
#
# ```python
# numbers = [1, 2, 3, 4, 5, 6]
# numToCheck = 2.2
#
# if numToCheck in numbers:
#           print("There")
# else:
#           print("Not there")
# ```
#
# **Selected Answer:**
# Correct
# False
#
# **Correct Answer:**
# Correct
# False
#
# #### Question 8
# 0.1 out of 0.1 points
#
# Predict the output of the following code:
#
# ```python
# X = 3
#
# if X > 2 or X < 5 and X > 6:
#           print("ok")
# else:
#           print("no output")
# ```
#
# **Selected Answer:**
# Correct
# no output
#
# **Correct Answer:**
# Correct
# no output
#
# #### Question 9
# 0.1 out of 0.1 points
#
# The two membership operators are ……….and …………
#
# **Selected Answer:**
# Correct
# in, not in
#
# **Correct Answer:**
# Correct
# in, not in
#
# #### Question 10
# 0.1 out of 0.1 points
#
# What keyword would you use to add an alternative condition to an if statement?
#
# **Selected Answer:**
# Correct
# elif
#
# **Correct Answer:**
# Correct
# elif
