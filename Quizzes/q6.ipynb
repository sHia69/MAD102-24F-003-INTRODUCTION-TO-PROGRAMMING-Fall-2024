# %% [markdown]
# # Question 1
# 0.05 out of 0.05 points
#
# What would be printed in the console for this code:
#
# ```python
# word = 'this is weird'
# print(word[-5:])
# ```
#
# Selected Answer:
# Correct
# weird
#
# Correct Answer:
# Correct
# weird
#
# # Question 2
# 0.05 out of 0.05 points
#
# A good practice is to apply any transformation to a string when it is first being read in.
#
# Selected Answer:
# Correct
# True
#
# Correct Answer:
# Correct
# True
#
# # Question 3
# 0.05 out of 0.05 points
#
# If I applied the title method to the string - 'This Is a Title', the resulting string returned would be ____
#
# Selected Answer:
# Correct
# This Is A Title
#
# Correct Answer:
# Correct
# This Is A Title
#
# # Question 4
# 0.05 out of 0.05 points
#
# This method is used to combine a list of strings with a designated separator value
#
# Selected Answer:
# Correct
# join()
#
# Correct Answer:
# Correct
# join()
#
# # Question 5
# 0 out of 0.05 points
#
# What would be printed in the console for this code:
#
# ```python
# word = 'this is weird'
# print(word[2:6:3])
# ```
#
# Selected Answer:
# Incorrect
# hi
#
# Correct Answer:
# Correct
# ii
#
# # Question 6
# 0.05 out of 0.05 points
#
# Choose the correct function declaration of `fun()` so that we can execute the following function call successfully
#
# ```python
# fun(12,18,19)
# fun(3,4,5,7)
# ```
#
# Selected Answer:
# Correct
# def fun(*data):
#
# Correct Answer:
# Correct
# def fun(*data):
#
# # Question 7
# 0.05 out of 0.05 points
#
# When determining alignment with a formatted string, this character tells the interpreter to align the characters on the left
#
# Selected Answer:
# Correct
# <
#
# Correct Answer:
# Correct
# <
#
# # Question 8
# 0.05 out of 0.05 points
#
# What is the output of the following function call
#
# ```python
# def outer_fun(a, b):
#           def inner_fun(c, d):
#                     return c + d
#           return inner_fun(a, b)
#           return a
#
# result = outer_fun(5, 10)
# print(result)
# ```
#
# Selected Answer:
# Correct
# 15
#
# Correct Answer:
# Correct
# 15
#
# # Question 9
# 0.05 out of 0.05 points
#
# I want to know if the first letter in a string is the letter w. To do this I can use the string method:
#
# Selected Answer:
# Correct
# startswith('w')
#
# Correct Answer:
# Correct
# startswith('w')
#
# # Question 10
# 0 out of 0.05 points
#
# What is output of below function?
#
# ```python
# def printMax(a, b):
#           if a > b:
#                     print(a, 'is maximum')
#           elif a == b:
#                     print(a, 'is equal to', b)
#           else:
#                     print(b, 'is maximum')
# printMax(3, 4)
# ```
#
# Selected Answer:
# Incorrect
# 4
#
# Correct Answer:
# Correct
# 4 is maximum
#
# # Question 11
# 0.05 out of 0.05 points
#
# ____ is the process of dividing a program into separate modules that can be developed and tested separately and integrated into a single program.
#
# Selected Answer:
# Correct
# Modular development
#
# Correct Answer:
# Correct
# Modular development
#
# # Question 12
# 0.05 out of 0.05 points
#
# This represents the value provided to a function's parameter during a function call.
#
# Selected Answer:
# Correct
# argument
#
# Correct Answer:
# Correct
# argument
#
# # Question 13
# 0.05 out of 0.05 points
#
# Which of the following will print the pi value defined in math module?
#
# Selected Answer:
# Correct
# from math import pi
# print(pi)
#
# Correct Answer:
# Correct
# from math import pi
# print(pi)
#
# # Question 14
# 0.05 out of 0.05 points
#
# This function returns the number of characters (including white space) that are in a string.
#
# Selected Answer:
# Correct
# len()
#
# Correct Answer:
# Correct
# len()
#
# # Question 15
# 0.05 out of 0.05 points
#
# When using the find method, when a substring is not found in the string being checked, the method returns ____
#
# Selected Answer:
# Correct
# -1
#
# Correct Answer:
# Correct
# -1
#
# # Question 16
# 0.05 out of 0.05 points
#
# The local variables of a particular function can be used inside other functions, but these cannot be used in global space.
#
# Selected Answer:
# Correct
# False
#
# Correct Answer:
# Correct
# False
#
# # Question 17
# 0.05 out of 0.05 points
#
# This is a special keyword that indicates no value. A function with no return statement, or a return statement with no following expression returns this value.
#
# Selected Answer:
# Correct
# None
#
# Correct Answer:
# Correct
# None
#
# # Question 18
# 0.05 out of 0.05 points
#
# What would be printed in the console with this code?
#
# ```python
# word = 'I know'
# print(word[0:3])
# ```
#
# Selected Answer:
# Correct
# I k
#
# Correct Answer:
# Correct
# I k
#
# # Question 19
# 0.05 out of 0.05 points
#
# Variables that are declared inside of a function have ______, which means they can not be accessed outside the function's body.
#
# Selected Answer:
# Correct
# local scope
#
# Correct Answer:
# Correct
# local scope
#
# # Question 20
# 0.05 out of 0.05 points
#
# When we create a function and then use it, we are calling the function.
#
# Selected Answer:
# Correct
# True
#
# Correct Answer:
# Correct
# True
